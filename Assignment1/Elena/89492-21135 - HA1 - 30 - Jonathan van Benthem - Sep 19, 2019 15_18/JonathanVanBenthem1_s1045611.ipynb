# %% [markdown]
# # Assignment 1
#
# ## Objective of this assignment
# The objective is to get acquainted with the Python language, with emphasis on its scientific and numerical extensions, how data can be imported from other data sources, the linear algebra basics that are needed for this course, visualization using principal component analysis (PCA) and the concept of similarity. Upon completing this exercise it is expected that you:
#
# - Understand how data can be represented as vectors and matrices in numerical Python (NumPy).
# - Can apply and interpret principal component analysis (PCA) for data visualization.
# - Understand the various measures of similarity such as Jaccard and Cosine similarity and apply similarity measures to query for similar observations.
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: `StudentName1_snumber_StudentName2_snumber.ipynb`
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Brightspace.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + Use the Brightspace discussion board or email the student assistants for questions on how to complete the exercises.
# + If you find mistakes/have suggestions/would like to complain about the assigment material itself, please email me [Lisa] at `l.tostrams@science.ru.nl`
#
#
# ## Advised Reading and Exercise Material
# **The following on-line materials are recommended:**
#
# - <http://docs.python.org/tutorial> - Introduction into Python environment, syntax and data structures. Recommended reading - sections 1, 2, 3, 4 and 5.
# - <https://docs.scipy.org/doc/numpy/user/quickstart.html> - Tutorial introducing the scientific computing in Python, array and matrix operations, indexing and slicing matrices.
# - <https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html> - Useful reference to scientific computing in Python if you have previous experience with MATLAB programming.
# - <https://www.datacamp.com/courses/intro-to-python-for-data-science> - Simple introduction to Data Science using Python.
# - <https://matplotlib.org/> - Documentation and examples related to matplotlib module, which we shall use extensively through the course to visualize data and results.
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, **Introduction to Data Mining**, sections 2.1-2.3 + (A) + B.1
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, **Introduction to Data Mining**, sections 2.4 + 3.1-3.2 + C.1-C.2
#
#
# ## 1.1 Python and Linear Algebra basics
#
# **For this course we advise to only use NumPy ndarrays to represent vectors and matrices. The numpy.matrix data type, although intuitive, is less supported and uses operators for multiplication differently. This means that you can't perform matrix multiplications symbollically, but that you will have to use functions from the NumPy library!**
#
# **1.1.1** a)(0.3 points) Generate (and print) the following vectors using functions from the *NumPy* package in Python:
# *Note: You do not have to print column vectors as columns!*
#
# \begin{equation}
#      \textbf{x} = \begin{pmatrix}
#          6 \\
#          7 \\
#          8 \\
#          9 \\
#          10 \\
#          11 \\
#          12
#        \end{pmatrix}
#      \textbf{y} = \begin{pmatrix}
#          3 \\
#          7 \\
#          11 \\
#          15 \\
#          19 \\
#          23 \\
#          27
#        \end{pmatrix}
#      \textbf{w} = \begin{pmatrix}
#          1 \\
#          1 \\
#          0 \\
#          0.5 \\
#          1 \\
#          1.5 \\
#          2 \\
#          0 \\
#          0
#        \end{pmatrix}
#      \textbf{s} = \begin{pmatrix}
#          100 \\
#          98.8 \\
#          97.6 \\
#          96.4 \\
#          95.2
#        \end{pmatrix}
#      \textbf{z} = \begin{pmatrix}
#          0.7 \\
#          1.0 \\
#          1.3 \\
#          1.6 \\
#          1.9 \\
#          2.2 \\
#          2.5 \\
#          2.8
#        \end{pmatrix}
#   \end{equation}

# %%
#Import NumPy
import numpy as np
#You'll have to manually import libraries in the future!

import platform;

print(platform.sys.version);
# Out:
# 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]

# %%
##Generate the vectors using Python and NumPy 
x = np.array([6, 7, 8, 9, 10, 11, 12])
y = np.array([3, 7, 11, 15, 19, 23, 27])
w = np.array([1,1, 0, 0.5, 1, 1.5, 2, 0,0])
s = np.array([100, 98.8, 97.6, 96.4, 95.2])
z = np.array([0.7, 1.0, 1.3, 1.6, 1.9, 2.2, 2.5, 2.8])

print(x)
print(y)
print(w)
print(s)
print(z)
# Out:
# [ 6  7  8  9 10 11 12]
# [ 3  7 11 15 19 23 27]
# [1.  1.  0.  0.5 1.  1.5 2.  0.  0. ]
# [100.   98.8  97.6  96.4  95.2]
# [0.7 1.  1.3 1.6 1.9 2.2 2.5 2.8]

# %% [markdown]
# Then compute the following operations:
# > b) (0.2 points) **v** = 3**x** + **y**

# %%
##Answer to question 1.1.1b
v = 3*x + y

print(v)
# Out:
# [21 28 35 42 49 56 63]

# %% [markdown]
# > c) (0.2 points) The dot product between **x** and **y** and name it **q**

# %%
##Answer to question 1.1.1c
# Dot product can be calculated (in python 3.7) with a '@' symbol
q = x @ y

print(q)
# Out:
# 1057

# %% [markdown]
# > d) (0.2 points) **t** = pi(**s** + 4) (element wise multiplication)

# %%
##Answer to question 1.1.1d
t = np.pi*s + np.pi*4

print(t)
# Out:
# [326.72563597 322.95572479 319.1858136  315.41590242 311.64599124]

# %% [markdown]
# > e) (0.2 points) **z** = **z** - 1

# %%
##Answer to question 1.1.1e
z = z - 1

print(z)
# Out:
# [-0.3  0.   0.3  0.6  0.9  1.2  1.5  1.8]

# %% [markdown]
# > f) (0.2 points) replace some values of x, such that the last three values in the vector are 4

# %%
##Answer to question 1.1.1f
print('original:', x)

# Get the last 3 values in the array and set/replace them to/with '4'
x[-3:] = 4

print('modified:', x)
# Out:
# original: [ 6  7  8  9 10 11 12]
# modified: [6 7 8 9 4 4 4]

# %% [markdown]
# > g) (0.2 points) **r** = 2**w** - 5

# %%
##Answer to question 1.1.1g
r = 2*w - 5

print(r)
# Out:
# [-3. -3. -5. -4. -3. -2. -1. -5. -5.]

# %% [markdown]
# **1.1.2** (0.25 points) Generate these matrices:
#
# \begin{equation}
#      \textbf{M} = \begin{pmatrix}
#          1 & 2 & 3 \\
#          6 & 8 & 4 \\
#          6 & 7 & 5
#          \end{pmatrix}
#      \textbf{N} = \begin{pmatrix}
#          4 & 6 \\
#          7 & 2 \\
#          5 & 1
#          \end{pmatrix}
#      \textbf{P} = \begin{pmatrix}
#          2 & 5 \\
#          5 & 5
#          \end{pmatrix}
# \end{equation}
#
# Afterwards try and compute the operations for subquestions *a* up to and including *e* and print the resulting matrix. If some operations yield errors, give the reason as to why that happens.
#
# *A hint: NumPy has functions for matrix operations you can, and should, use! For instance, * **M\*N** * should be calculated with NumPy's `dot` product.*

# %%
##Generate the matrices using Python and NumPy

M = np.matrix('1 2 3; 6 8 4; 6 7 5')
N = np.matrix('4 6; 7 2; 5 1')
P = np.matrix('2 5; 5 5')

print(M)
print(N)
print(P)
# Out:
# [[1 2 3]
#  [6 8 4]
#  [6 7 5]]
# [[4 6]
#  [7 2]
#  [5 1]]
# [[2 5]
#  [5 5]]

# %% [markdown]
# > a. (0.2 points) **A** = **MN** + **N**

# %%
##Answer to question 1.1.2a
A = M@N + N

print(A)
# Out:
# [[ 37  19]
#  [107  58]
#  [103  56]]

# %% [markdown]
# > b. (0.2 points) **B** = **N**<sup>T</sup>**M**

# %%
##Answer to question 1.1.2b
B = N.transpose()@M

print(B)
# Out:
# [[76 99 65]
#  [24 35 31]]

# %% [markdown]
# > c. (0.2 points) **C** = **P**<sup>-1</sup> + **P**

# %%
##Answer to question 1.1.2c

# P-1 means the inverse of P. Inverse in python is notated with '.I'

C = P.I + P

print(C)
# Out:
# [[1.66666667 5.33333333]
#  [5.33333333 4.86666667]]

# %% [markdown]
# > d. (0.2 points) **D** = **AC**(**C** + **B**)

# %%
##Answer to question 1.1.2d

AtimesC = A@C
# CplusB =  C + B gives an error
# D = AtimesC*CplusB
# print (D)

print ('A x C works')
print ('but (C + B) does not work: ValueError: operands could not be broadcast together with shapes (2,2) (2,3)')
print ('Can\'t multiply things that are not of the same shape')
print ('We can however pad C to match the shape of D')

C1 = np.pad(C,([0,0],[0,1]), 'constant') # C1 shape = (2,3)

D = AtimesC@(C1 + B)

print ('D after modifying C:', D)
# Out:
# A x C works
# but (C + B) does not work: ValueError: operands could not be broadcast together with shapes (2,2) (2,3)
# Can't multiply things that are not of the same shape
# We can however pad C to match the shape of D
# D after modifying C: [[21160.46666667 28559.69333333 19578.8       ]
#  [62894.82222222 84883.49777778 58139.26666667]
#  [60637.31111111 81836.52888889 56049.53333333]]

# %% [markdown]
# > e. (0.2 points) Compute the eigenvalues and eigenvectors of **M**, **N**, and **P** (and print them).

# %%
##Answer to question 1.1.2e

# Compute eigenvalues
eigenValuesM = np.linalg.eigvals(M)
#eigenvaluesN = np.linalg.eigvals(N) not a square
eigenValuesP = np.linalg.eigvals(P)

# Compute eigenvectors
eigenVectM = np.linalg.eig(M)
#eigenVectN = np.linalg.eig(N) not a square
eigenVectP = np.linalg.eig(P)

print('M eigenvalues:', eigenValuesM)
print('M eigenvectors:', eigenVectM)
print()
#print('N eigenvalues:', eigenValuesN)
#print('N eigenvectors:', eigenVectN)
print()
print('P eigenvalues:', eigenValuesP)
print('P eigenvectors:', eigenVectP)
# Out:
# M eigenvalues: [14.26208735 -1.26208735  1.        ]
# M eigenvectors: (array([14.26208735, -1.26208735,  1.        ]), matrix([[-0.25759308, -0.84234218,  0.51507875],
#         [-0.68324439,  0.38109032, -0.71318597],
#         [-0.68324439,  0.38109032,  0.47545731]]))
#
#
# P eigenvalues: [-1.72015325  8.72015325]
# P eigenvectors: (array([-1.72015325,  8.72015325]), matrix([[-0.80229293, -0.59693053],
#         [ 0.59693053, -0.80229293]]))

# %% [markdown]
# # Intermezzo: proper scientific plotting practices
#
# **In this course and many others** you will be asked to make a lot of plots. If you've ever read an academic paper, you'll have noticed that besides axis labels, titles and legends, these also contain a figure description *for each plot*. The idea is that you can 'read' a figure without skimming through the text for the explanation. So these figure descriptions should contain
#
# 1. A description in natural language explaining what we're looking at,
# 2. references to the axis labels if these are not clear immediately, and
# 3. provide a short answer to the question that it belongs to.
#
# ### Examples:

# %%
import matplotlib.pyplot as plt
import numpy as np
numbers = np.arange(100,1001,100)

# Simple plot
plt.plot(numbers)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Numbers')
plt.show()
print('Figure 1: an example of a simple plot. X axis shows the index of each element, the Y axis shows increasing numbers.')

# a little more complex plot
indices = np.arange(5,15)
plt.scatter(indices,numbers)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Numbers')
plt.show()
print('Figure 2: an example of a slightly more complex plot, where we explicitely set the values on the X axis. X axis shows the index of each element, the Y axis shows increasing numbers.')


# an incredibly unnecessary complex plot
import seaborn as sns # nicer graphics
sns.set_style('darkgrid')

fig,ax = plt.subplots(3,2,figsize=(8,8)) # create 3 rows of 2 columns of subplots
ax = ax.ravel()

x = np.random.normal(0.1, 1,10) #10 numbers with a mean of 0.1 and a sigma of 1
y = np.random.normal(1, 0.1,10) #10 numbers with a mean of 1 and a sigma of 0.1

ax[0].plot(x,y,'k.') # k means black and . means it should plot dots. Similarly, 'r-' results in a red line and 
                    # 'b--' would result in a blue checkered line.
ax[0].set_title('Random black dots using x and y as coords')
ax[0].set_ylabel('Row 0 of subplots')
ax[1].bar(range(0,10),x,color='orange') #the first argument tells plt where to place the bars, so range(0,10) just puts them on 0,..,9
ax[1].set_title('Vertical bars of x values')

ax[2].barh(range(0,10),y,color='darkblue')
ax[2].set_title('Horizontal bars of y values')
ax[2].set_ylabel('Row 1 of subplots')
from scipy import ndimage 

im = np.zeros((28, 28)) # creates an 28x28 array of zeros
points = 28 * np.random.random((2, 3 ** 2)) # creates 28 random (x,y) pairs that we will use as indices
im[(points[0]).astype(np.int), (points[1]).astype(np.int)] = 1 # sets the value at those indices to 1
im = ndimage.gaussian_filter(im, sigma=28 / (4. * 3)) # puts the array through an image filter that 
                                                        # blurs the 0's and 1's together
blobs = (im > im.mean())*255 # seperates them back into 0's and 1's after blurring 

ax[3].imshow(blobs,cmap='gray') # plots the array as an image, where each pixel corresponds to a 0 or 1 in our array
ax[3].set_title('Blobs in black and white')

ax[4].hist(im.ravel(), bins=12,color='green',rwidth=0.9) # plot the gray values from the array in a histogram with 12 bins
ax[4].set_title('Distribution of grayvalues')
ax[4].set_ylabel('Row 2 of subplots')
ax[4].set_xlabel('Column 0 of subplots')
ax[5].hist(im.ravel(),bins=12, cumulative=True, color='orange',rwidth=0.9,alpha=0.8,label='summed') # plot a see through 
                                                                                # cumulative histogram with alpha
ax[5].hist(im.ravel(), bins=12,color='green',rwidth=0.9,alpha=0.7,label='values') # plot the gray values from the array in a histogram with 12 bins
ax[5].set_title('(Cumulative) Distribution of grayvalues')
ax[5].legend()
ax[5].set_xlabel('Column 1 of subplots')
plt.tight_layout() # makes sure everything fits without overlapping -- try running this cell without this to see the effect

plt.show()

print('Figure 3: an example of a complex plot, which showcases some neat pretty stuff that matplotlib can do! Seaborn is a library that you can use to make your plots look nicer. Subplots are used to create multiple plots within the same figure. First I plotted some random black dots, and then I used the bar functions to plot the same information but more complicated. imshow can be used to plot your array as an image for easy inspection. Here, I created an image of blobs using random numbers and a gaussian blur filter. Histograms are nice for checking distributions, for instance, the distribution of gray values in an image containing blobs!')
sns.reset_orig()
# Out:
# Figure 1: an example of a simple plot. X axis shows the index of each element, the Y axis shows increasing numbers.
# Figure 2: an example of a slightly more complex plot, where we explicitely set the values on the X axis. X axis shows the index of each element, the Y axis shows increasing numbers.
# Figure 3: an example of a complex plot, which showcases some neat pretty stuff that matplotlib can do! Seaborn is a library that you can use to make your plots look nicer. Subplots are used to create multiple plots within the same figure. First I plotted some random black dots, and then I used the bar functions to plot the same information but more complicated. imshow can be used to plot your array as an image for easy inspection. Here, I created an image of blobs using random numbers and a gaussian blur filter. Histograms are nice for checking distributions, for instance, the distribution of gray values in an image containing blobs!

# %% [markdown]
# ## 1.2 Principal Component Analysis
#
# **1.2.1** many experimenters have a habit of using Microsoft Excel as their tool to record measurements from experiments. Fortunately Python can read Excel files. Various methods exist, of which the use of the Python library Pandas is arguably one of the easiest for the purpose of Data Mining.
#
# The data used in this exercise is based on data from a chemical sensor obtained from the NanoNose project[1]. The data contains 8 sensors, named by the letters A-H, measuring the concentration of Water, Ethanol, Acetone, Heptane and Pentanol injected into a small gas chamber. The data will be represented in matrix form such that each column contains the 8 sensor measurements (i.e., sensor A-H) of the various compounds injected into the gas chamber.
# > a. (0.2 points) Inspect the nanonose.xls file in the Data folder and make sure you understand how the data is stored in Excel.
#
# > *Load the data in python using the Pandas library (use the `read_excel()` function). Make sure you read some of the Pandas documentation! Especially (column) slicing, (row) indexing and dropping are useful commands to get the correct data here.*
#
# > *Make sure to inspect the data first. **You should cut out some rows and columns! You can easily inspect the structure of the Pandas dataframe by printing the `head()` function.***
#
# > *You should see the 8 columns named A-H and the first 5 rows by printing `head()`.*
#
# > *Finally use the `.values` function to cast the Pandas dataframe to a NumPy array called **X**. *

# %%
import pandas as ps

file = ps.read_excel('Data/nanonose.xls')

## Get infortmation from the sheet
print(type(file)) # DataFrame

file.shape #  91 rows, 11 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (91, 11)

# %%
## Top of the file
file.head()
# Out:
#       Nanonose     Unnamed: 1  Unnamed: 2     A     B    C          D  \
# 0  Sample type  Concentration         NaN   NaN   NaN  NaN        NaN
# 1        Water           9200         NaN  95.5  21.0  6.0  11.942308
# 2        Water           9200         NaN  94.5  17.0  5.0   5.484615
# 3        Water           9200         NaN  92.0  16.0  3.0  11.057692
# 4        Water           4600         NaN  53.0   7.5  2.5   3.538462
#
#            E          F         G         H
# 0        NaN        NaN       NaN       NaN
# 1  64.134615  21.498560  5.567840  1.174135
# 2  63.205769  19.658560  4.968000  1.883444
# 3  62.586538  19.813120  5.192480  0.564835
# 4  35.163462   6.876207  1.641724  0.144654

# %%
## Botom of the file
file.tail()
# Out:
#     Nanonose Unnamed: 1  Unnamed: 2      A         B         C     D      E  \
# 86  Pentanol        192         NaN  0.192  3.072000  9.120000 -0.25  1.300
# 87  Pentanol        192         NaN  0.192  2.496000  8.736000 -0.25  1.125
# 88  Pentanol        103         NaN  0.000  1.287500  5.579167  0.00  0.650
# 89  Pentanol        103         NaN  0.000  1.072917  4.935417  0.00  0.800
# 90  Pentanol        103         NaN  0.000  1.716667  6.437500  0.00  0.800
#
#            F          G    H
# 86  4.787200  11.219200  0.0
# 87  5.068800  12.044800  0.0
# 88  1.845417   6.695000  0.0
# 89  2.288889   7.024028  0.0
# 90  1.945556   7.066944  0.0

# %%
## skip row 0 (start from 1) and start at column 4 (skip 0, 1, 2, 3)
df = file.iloc[1:, 3:]

df.head()
# Out:
#       A     B    C          D          E          F         G         H
# 1  95.5  21.0  6.0  11.942308  64.134615  21.498560  5.567840  1.174135
# 2  94.5  17.0  5.0   5.484615  63.205769  19.658560  4.968000  1.883444
# 3  92.0  16.0  3.0  11.057692  62.586538  19.813120  5.192480  0.564835
# 4  53.0   7.5  2.5   3.538462  35.163462   6.876207  1.641724  0.144654
# 5  51.0   7.5  2.5   4.865385  34.057692   6.757241  1.613966  0.059663

# %%
df.shape
# Out:
# (90, 8)

# %%
df.describe()
# Out:
#                A           B          C           D           E          F  \
# count  90.000000   90.000000  90.000000   90.000000   90.000000  90.000000
# mean    9.465267   20.327234  10.498268   23.430042   27.714146  15.321816
# std    19.110097   27.921853  10.559550   45.182924   37.429763  20.854314
# min     0.000000   -0.500000   0.000000   -3.000000    0.000000  -0.062270
# 25%     0.500000    1.554167   2.500000    0.000000    1.536096   1.268763
# 50%     2.000000    6.850000   8.000000    3.456731    9.288462   5.623834
# 75%     8.250000   26.750000  14.425000   16.500000   37.898438  21.493868
# max    95.500000  128.000000  51.000000  235.529412  142.500000  74.328800
#
#                G           H
# count  90.000000   90.000000
# mean   16.026104   20.094031
# std    15.624580   42.531244
# min     0.054486    0.000000
# 25%     1.747238    0.092795
# 50%    10.669600    3.321705
# 75%    29.535782   18.166553
# max    55.109600  207.830304

# %%
## Make a matrix out of the dataframe
X = df.values 
print(type(X)) # matrix is a ndarray
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# > b. (0.3 points) The data resides in what can be seen as an 8-dimensional space. Each dimension (column), corresponds to one of the 8 NanoNose sensors. Multidimensional (>3) data is hard to visualize, as we are unable to plot that many dimensions simultaneously.
#
# > Using the `matplotlib.pyplot` library, plot the attributes A and B against each other. After you have plotted A against B, also plot a few other combinations of attributes. Plot at least 4 different combinations.
#
# > *Do not forget to label your axes and add a figure description!*
#
# > NOTE: If you want to plot inside the Jupyter notebook without calling `plt.show()` after each plot, use the following command after you imported the `matplotlib.pyplot` library:
# *%matplotlib inline*

# %%
## Map the ndarray 'columns' to a letter (representing the columns from the original file).
A = X[:,0]
B = X[:,1]
C = X[:,3]
D = X[:,4]
E = X[:,5]
F = X[:,6]
G = X[:,7]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
fig, axs = plt.subplots(2, 2, figsize=(15,15))
# A against B
axs[0, 0].scatter(A, B)
axs[0, 0].set_title('Attribute A against attribute B')
axs[0, 0].set(xlabel='Attribute A values', ylabel='Attribute B values')
# B against C
axs[0, 1].scatter(B, C)
axs[0, 1].set_title('Attribute B against attribute C')
axs[0, 1].set(xlabel='Attribute B values', ylabel='Attribute C values')
# D against E
axs[1, 0].scatter(D, E)
axs[1, 0].set_title('Attribute D against attribute E')
axs[1, 0].set(xlabel='Attribute D values', ylabel='Attribute E values')
# F against G
axs[1, 1].scatter(F, G)
axs[1, 1].set_title('Attribute F against attribute G')
axs[1, 1].set(xlabel='Attribute F values', ylabel='Attribute G values')

# No overlap for the texts on the graphs
plt.tight_layout()
plt.show()

print ('Figure 1: Plotting the different attributes from the matrix against eachother in a 2 dimensional space')
# Out:
# Figure 1: Plotting the different attributes from the matrix against eachother in a 2 dimensional space

# %% [markdown]
# 1.2.2 Principal Component Analysis, more commonly known as PCA, can be used to visualize high dimensional data.
#
# > a. (1 point) Explain what PCA is and when it can be used. Make sure to provide an in-depth explanation and note what the drawbacks and limitations are.

# %% [markdown]
# <b>
# Principal Components Analysis (PCA)
#
# - is a linear algebra technique for continuous attributes that finds new attributes (principal components) that (1) are linear combinations of the original attributes, (2) are orthogonal (perpendicular) to each other, and (3) capture the maximum amount of variation in the data. For example, the first two principal components capture as much of the variation in the data as is possible with two orthogonal attributes that are linear combinations of the original attributes.
# - is a Linear Algebra Techniques for Dimensionality Reduction, using techniques from linear algebra to project the data from a high-dimensional space into a lower-dimensional space
#
# - has several appealing characteristics. First, it tends to identify the strongest patterns in the data. Hence, PCA can be used as a pattern-finding technique. Second, often most of the variability of the data can be captured by a small fraction of the total set of dimensions. As a result, dimensionality reduction using PCA can result in relatively low-dimensional data and it may be possible to apply techniques that don't work well with high-dimensional data. Third, since the noise in the data is (hopefully) weaker than the patterns, dimensionality reduction can eliminate much of the noise. This is beneficial both for data mining and other data analysis algorithms.
#
# Limitations:
#
# - Calculating PCA on a dataset with lots of objects is slow and will only slow down the more objects there are. Which makes it a bad solution for huge datasets.
#
# - PCA is only for finding linear relationships in the data.
# </b>

# %% [markdown]
# To apply PCA we must first mean center the data. Mean centering means that the mean value for an attribute (i.e. a column) is subtracted from all values for that attribute.
#
# > b. (0.5 points) Why do we first need to mean center the data before applying PCA?

# %% [markdown]
# <b>If we don't standardize the variables before applying PCA, we will get misleading directions.
#
# PCA (Principal Component Analysis) finds new directions based on covariance matrix of original variables. Covariance matrices are sensitive to standardization of variables. Usually, there is a standardization process to assign equal weights to all the variables.
#
# There will be different principal components if the data isn't standardized before applying PCA. We need all the data to have roughly the same meaning.</b>

# %% [markdown]
# In practice, applying PCA comes down to a series of matrix operations, this is useful, as matrix operations can be applied with little effort and can be computed in relatively little time.
#
# The given data **X** must first be mean centered. This can be easily done by calculating a row vector **μ** containing the mean values of each attribute. Then you can subtract **μ** from **X** (**Y** = **X** - **μ**, where **μ** is subtracted from every row.).
#
# Then, the Singular Value Decomposition (or SVD) of **Y**, the now mean centered data, can be calculated. **Y** = **USV**<sup>T</sup>. In practice, this is often done using the `numpy.linalg.svd()` function.
#
# Using SVD on **Y** yields 3 matrices **U**, **S** and **V**<sup>T</sup>. These are used to project the data onto specific Principal Components (PCs).
#
# The entire dataset can be projected onto the Principal Components by multiplying **Z** = **Y\*V**, where **Z** indicates the projected data, and **Z[:,0]** indicates the data projected onto the first PC. Alternatively, one could project onto just a subset of all the PCs by indexing in the multiplication. For example: **Z** = **Y\*V[:,0]** would also yield the projection of the data onto the first PC.
#
# _Note that for matrices, the notation **Y\*V** denotes the `dot` product between **Y** and **V**!_
#
# > c. (1 point)  Apply PCA (using the aforementioned method) on the Nanonose data and visualize a scatterplot of the projection of the data onto the first two PCs.

# %%
# calculate the mean
u = X.mean(axis=0)

# Mean centering 
Y = X - u

# Singlular Value Decomposition
U, s, V = np.linalg.svd(Y)

# %%
# Project the dataset onto the Principal Components use dot function and reverse transpose V.T to V (by using .T)
Z = Y@V.T
# 2nd method of getting the desired projections
Z1 = Y@V.T[:,0]
Z2 = Y@V.T[:,1]

# Plot the Z's
fig, axs = plt.subplots(2, figsize=(15,15))
axs[0].scatter(Z[:,0],Z[:,1])
axs[0].set_title('First PC against Second PC using the full V')
axs[0].set(xlabel= 'First PC values', ylabel='Second PC values')

# Include the 2nd method variables to proof it gives the same results
axs[1].scatter(Z1,Z2) 
axs[1].set_title('First PC against Second PC using 1st and 2nd projections from V')
axs[1].set(xlabel= 'First PC values', ylabel='Second PC values')

plt.show()

print('Figure 2: First PC against Second PC using both methods')
# Out:
# Figure 2: First PC against Second PC using both methods

# %% [markdown]
# > d. (1 point) Alternatively, one could use EigenValue Decomposition, EVD, instead of SVD. What are the similarities and differences between SVD and EVD? Can both be applied in each case?

# %% [markdown]
# <b>
#
# Similarities:
#  - Finding patterns in matrices. For potential dimension reduction.
#
# Differences:
# - The eigendecomposition uses only one basis, i.e. the eigenvectors, while he SVD uses two different bases, the left and right singular vectors.
#
# - The basis of the eigendecomposition is not necessarily orthogonal, the eigenbasis of the SVD is orthonormal!
#
# Every matrix has a SVD, no questions asked - it does not need to be square or fulfill any other requirements. On the other hand, not even every square matrix has an eigendecomposition.
# </b>

# %% [markdown]
# PCA attempts to explain as much of the variance in data with as few PCs as possible. The variance explained by each of the PCs **m** can be calculated using the following formula:
# $$\rho_m = 1 - \frac{\|{Y} - {u}_m s_{mm} {v}_m^T\|^2_F}{\|{Y}\|^2_F} = \frac{s_{mm}^2}{\displaystyle \sum_{m'=1}^M s^2_{m'm'}}$$
#
# Which indicates that the variation $\rho$ for a given **m** can be calculated by dividing the squared singular value of component **m** by the sum of all squared singular values.
# > e. (1 point) Calculate the row vector $\rho$ containing all values of $\rho$ for all PCs **m**. Create a bar plot with the variance explained on the Y axis and the number of the PC on the X axis.

# %%
p=(s*s)/(sum(s*s))

# %%
# The shape of p(and s) is 8 so the bar chart should have a range of 8
p.shape
# Out:
# (8,)

# %%
plt.bar(range(8), p)
plt.xlabel('PC #number')
plt.ylabel('Amount of the variance')
plt.title('Amount of variance explained per PC')
plt.show()
print('Figure 3: Bar chart representing the amount of variance distributed amongst all PC\'s in the NanoNoze dataset')
# Out:
# Figure 3: Bar chart representing the amount of variance distributed amongst all PC's in the NanoNoze dataset

# %% [markdown]
# > f. (0.5 points) How much of the variance is explained by the first three PCs?

# %%
# Add the values of the first 3 PC's together
pVariance = sum(p[0:3])

print('The sum of the first three PC\'s is :', pVariance)
print('The first three PC\'s account for ~', round(pVariance, 2)*100,'% of the variance')
# Out:
# The sum of the first three PC's is : 0.9274485381517034
# The first three PC's account for ~ 93.0 % of the variance

# %% [markdown]
# The columns of **V** indicate the exact projection of the data onto the PCs. In a way, a PC is nothing other than a linear combination of the original attributes.
# > g. (0.5 points) Which attributes are primarily represented by the first PC? What would cause an observation to have a large negative/positive projection onto the second principal component?

# %%
# The first column of V gives us the representation of the various attributes onto the first PC.
print(V[:,0])

print('Attribute C negatively represents by: ',V[2,0])
print('Attribute F negatively represents by: ',V[5,0])
print('Attribute B negatively represents by: ',V[1,0])
# Out:
# [ 0.03754331 -0.37748501 -0.77356029 -0.23125246  0.0038812  -0.43806921
#   0.10834769  0.02373672]
# Attribute C negatively represents by:  -0.77356028649639
# Attribute F negatively represents by:  -0.43806921031735896
# Attribute B negatively represents by:  -0.37748500894122966

# %% [markdown]
# <b>If the 2nd principal component lies far from the origin and parallel to the projection.</b>

# %% [markdown]
# ## 1.3 Similarity measures
#
# We will use a subset of the data on wild faces described by Berg in 2005 transformed to a total
# of 1000 grayscale images of size 40x40 pixels, we will attempt to find faces in the
# data base that are the most similar to a given query face. To measure similarity we
# will consider the following measures: SMC, Jaccard, Cosine, ExtendedJaccard, and
# Correlation. These measures of similarity are described in *Introduction to Data Mining*, page 73-77 and are given by
#
# \begin{eqnarray*}
# \textrm{SMC}({x},{y}) & = & \frac{\textrm{Number of matching attribute values}}{\textrm{Number of attributes}} \\
# \textrm{Jaccard}({x},{y}) & = & \frac{\textrm{Number of matching presences}}{\textrm{Number of attributes not involved in 00 matches}} \\
# \textrm{Cosine}({x},{y}) & = & \frac{{x}^T {y}}{\|{x}\| \|{y}\|} \\
# \textrm{ExtendedJaccard}({x},{y}) & = & \frac{{x}^T {y}}{\|{x}\|^2 + \|{y}\|^2 - {x}^T {y}} \\
# \textrm{Correlation}({x},{y}) & = & \frac{\textrm{cov}({x},{y})}{\textrm{std}({x}) \textrm{std}({y})}
# \\
# \end{eqnarray*}
# <br>where $\textrm{cov}({x},{y})$ denotes the covariance between ${x}$ and ${y}$ and $\textrm{std}({x})$ denotes the standard deviation of ${x}$.
#
# Notice that the SMC and Jaccard similarity measures only are defined for binary data, i.e., data that takes values in $\{0,1\}$. As the data we analyze is non-binary, the script will transform the data to be binary when calculating these two measures of similarity by setting
#
# $$x_i = \left\{ \begin{array}{ll} 0 & \textrm{if~} x_i < \textrm{median}({x}) \\
#                                 1 & \textrm{otherwise.} \end{array} \right.$$
#
# ### 1.3.1
# > a) (0.5 points) Inspect and run the simfaces function from the Toolbox. The function loads the CBCL face database, computes the similarity between a selected query image and all others, and display the query image, the 5 most similar images, and the 5 least similar images. The value of the used similarity measure is shown below each image. Try changing the query image and the similarity measure and see what happens. Which similarity measures produce similar results? Which one gives the best result? Why?
#
# > Give a quick overview of the settings (image number and similarity measure) for each time you run the script. Remember to leave results open!

# %%
from Toolbox.simfaces import simfaces

# %%
# Using simface 50
for i in ['SMC','Jaccard', 'Cosine', 'ExtendedJaccard', 'Correlation']:
        simfaces(50,i)
        print ('Using simface 1 and using the method "', i, '" to measure the similarity')
# Out:
# Using simface 1 and using the method " SMC " to measure the similarity
# Using simface 1 and using the method " Jaccard " to measure the similarity
# Using simface 1 and using the method " Cosine " to measure the similarity
# Using simface 1 and using the method " ExtendedJaccard " to measure the similarity
# Using simface 1 and using the method " Correlation " to measure the similarity

# %%
# Using simface 80
for i in ['SMC','Jaccard', 'Cosine', 'ExtendedJaccard', 'Correlation']:
        simfaces(80,i)
        print ('Using simface 2 and using the method "', i, '" to measure the similarity')
# Out:
# Using simface 2 and using the method " SMC " to measure the similarity
# Using simface 2 and using the method " Jaccard " to measure the similarity
# Using simface 2 and using the method " Cosine " to measure the similarity
# Using simface 2 and using the method " ExtendedJaccard " to measure the similarity
# Using simface 2 and using the method " Correlation " to measure the similarity

# %% [markdown]
# <b>
#
# Similair:
# - On face 80 there seems to be some reocurring similair face (47) between all types of methods except Jaccard.
#
#
# Best:
# - In my opinion "Correlation" seems to get the best result on face 50.
#    - The angle of the face and the grey values seem to line up the best
# - In my opinion "Cosine" seems the best for face 80.
#    - Looks like the similarity is most likely the result of lighting conditions.
#
# </b>

# %% [markdown]
# > b) (0.75 points) We will investigate how scaling and translation impact the following three
# similarity measures: Cosine, ExtendedJaccard, and Correlation. Let **x** and **y** be two small vectors of the same size. Let $\alpha$ and $\beta$ be two constants. You can generate these randomly or set them as you see fit. Using Python, calculate the following similarity measures, and check if the statements below are correct.
#
# \begin{eqnarray*}
# \textrm{Cosine}(\alpha{x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \textrm{ExtendedJaccard}(\alpha{x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \textrm{Correlation}(\alpha{x},{y}) & = & \textrm{Correlation}({x},{y}) \\
# \textrm{Cosine}(\beta + {x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \textrm{ExtendedJaccard}(\beta + {x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \textrm{Correlation}(\beta + {x},{y}) & = & \textrm{Correlation}({x},{y})
# \end{eqnarray*}
#
# > Type `help similarity` or study `similarity.py` to learn about the function that is used to compute the similarity measures. Do not forget to also import similarity.py!
#
# > Even though a similarity measure is theoretically invariant e.g.\ to scaling, it might not be exactly invariant numerically.
#
# > Do not forget to also provide an explanation in addition to the calculations!

# %%
from Toolbox.similarity import similarity

help (similarity)

x = np.array([1, 2, 3, 4])
y = np.array([5, 6, 7, 8])
a = 2
b = 3

def is_correct(result):
    if result != 0:
        return 'incorrect'
    else:
        return 'correct'
# Out:
# Help on function similarity in module Toolbox.similarity:
#
# similarity(X, Y, method)
#     SIMILARITY Computes similarity matrices
#
#     Usage:
#         sim = similarity(X, Y, method)
#
#     Input:
#     X   N1 x M matrix
#     Y   N2 x M matrix
#     method   string defining one of the following similarity measure
#            'SMC', 'smc'             : Simple Matching Coefficient
#            'Jaccard', 'jac'         : Jaccard coefficient
#            'ExtendedJaccard', 'ext' : The Extended Jaccard coefficient
#            'Cosine', 'cos'          : Cosine Similarity
#            'Correlation', 'cor'     : Correlation coefficient
#
#     Output:
#     sim Estimated similarity matrix between X and Y
#         If input is not binary, SMC and Jaccard will make each
#         attribute binary according to x>median(x)
#
#     Copyright, Morten Morup and Mikkel N. Schmidt
#     Technical University of Denmark

# %% [markdown]
# \begin{eqnarray*}
# \textrm{Cosine}(\alpha{x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \end{eqnarray*}

# %%
cosResult = similarity(a*x, y, 'cos') - similarity(x, y, 'cos')
print('cosResult is: ', cosResult, ' therefore the statement above is', is_correct(cosResult))
print('Because Cosine similarity is not effected by magnitude modification')
# Out:
# cosResult is:  [[0.]]  therefore the statement above is correct
# Because Cosine similarity is not effected by magnitude modification

# %% [markdown]
# \begin{eqnarray*}
# \textrm{ExtendedJaccard}(\alpha{x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \end{eqnarray*}

# %%
extResult = similarity(a*x, y, 'ext') - similarity(x, y, 'ext')
print('extResult is: ', extResult, ' therefore the statement above is', is_correct(extResult))
print('Because you are comparing 2 different arrays and so the result will differ')
# Out:
# extResult is:  [[0.38670285]]  therefore the statement above is incorrect
# Because you are comparing 2 different arrays and so the result will differ

# %% [markdown]
# \begin{eqnarray*}
# \textrm{Correlation}(\alpha{x},{y}) & = & \textrm{Correlation}({x},{y}) \\
# \end{eqnarray*}

# %%
corResult = similarity(a*x, y, 'cor') - similarity(x, y, 'cor')
print('corResult is: ', corResult, ' therefore the statement above is', is_correct(corResult))
print('Because a linear transformation doesn\'t effect a correlation')
# Out:
# corResult is:  [[0.]]  therefore the statement above is correct
# Because a linear transformation doesn't effect a correlation

# %% [markdown]
# \begin{eqnarray*}
# \textrm{Cosine}(\beta + {x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \end{eqnarray*}

# %%
cosResult = similarity(b + x, y, 'cos') - similarity(x, y, 'cos')
print('cosResult is: ', cosResult, ' therefore the statement above is', is_correct(cosResult))
print('Because Cosine similarity is effected by angle modification')
# Out:
# cosResult is:  [[0.03067984]]  therefore the statement above is incorrect
# Because Cosine similarity is effected by angle modification

# %% [markdown]
# \begin{eqnarray*}
# \textrm{ExtendedJaccard}(\beta + {x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \end{eqnarray*}

# %%
extResult = similarity(b + x, y, 'ext') - similarity(x, y, 'ext')
print('extResult is: ', extResult, ' therefore the statement above is', is_correct(extResult))
print('Because you are comparing 2 different arrays and so the result will differ')
# Out:
# extResult is:  [[0.45129615]]  therefore the statement above is incorrect
# Because you are comparing 2 different arrays and so the result will differ

# %% [markdown]
# \begin{eqnarray*}
# \textrm{Correlation}(\beta + {x},{y}) & = & \textrm{Correlation}({x},{y})
# \end{eqnarray*}

# %%
corResult = similarity(b + x, y, 'cor') - similarity(x, y, 'cor')
print('corResult is: ', corResult, ' therefore the statement above is', is_correct(corResult))
print('Because a linear transformation doesn\'t effect a correlation')
# Out:
# corResult is:  [[0.]]  therefore the statement above is correct
# Because a linear transformation doesn't effect a correlation
