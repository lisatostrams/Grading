# %% [markdown]
# Jorre Vedder S4379101
#
# # Assignment 1
#
#
# ## 1.1 Python and Linear Algebra basics
#
# **For this course we advise to only use NumPy ndarrays ndarrays to represent vectors and matrices. The numpy.matrix data type, although intuitive, is less supported and uses operators for multiplication differently. This means that you can't perform matrix multiplications symbollically, but that you will have to use functions from the NumPy library!**
#
# **1.1.1** (0.3 points) Generate (and print) the following vectors using functions from the *NumPy* package in Python:
# *Note: You do not have to print column vectors as columns!*
#
# \begin{equation}
#      \textbf{x} = \begin{pmatrix}
#          6 \\
#          7 \\
#          8 \\
#          9 \\
#          10 \\
#          11 \\
#          12
#        \end{pmatrix}
#      \textbf{y} = \begin{pmatrix}
#          3 \\
#          7 \\
#          11 \\
#          15 \\
#          19 \\
#          23 \\
#          27
#        \end{pmatrix}
#      \textbf{w} = \begin{pmatrix}
#          1 \\
#          1 \\
#          0 \\
#          0.5 \\
#          1 \\
#          1.5 \\
#          2 \\
#          0 \\
#          0
#        \end{pmatrix}
#      \textbf{s} = \begin{pmatrix}
#          100 \\
#          98.8 \\
#          97.6 \\
#          96.4 \\
#          95.2
#        \end{pmatrix}
#      \textbf{z} = \begin{pmatrix}
#          0.7 \\
#          1.0 \\
#          1.3 \\
#          1.6 \\
#          1.9 \\
#          2.2 \\
#          2.5 \\
#          2.8
#        \end{pmatrix}
# \end{equation}

# %%
#Import NumPy
import numpy as np
#You'll have to manually import libraries in the future!

# %%
##Generate the vectors in  using Python and NumPy 
x = np.array([6,7,8,9,10,11,12])
y = np.array([3,7,11,15,19,23,27])
w = np.array([1,1,0,0.5,1,1.5,2,0,0])
s = np.array([100,98.8,97.6,96.4,95.2])
z = np.array([0.7,1.0,1.3,1.6,1.9,2.2,2.5,2.8])

# %%
print(x)
print(y)
print(w)
print(s)
print(z)
# Out:
# [ 6  7  8  9 10 11 12]
# [ 3  7 11 15 19 23 27]
# [1.  1.  0.  0.5 1.  1.5 2.  0.  0. ]
# [100.   98.8  97.6  96.4  95.2]
# [0.7 1.  1.3 1.6 1.9 2.2 2.5 2.8]

# %% [markdown]
# Then compute the following operations:
# > a. (0.2 points) **v** = 3**x** + **y**

# %%
##Answer to question 1.1.1a
v = 3*x + y
print(v)
# Out:
# [21 28 35 42 49 56 63]

# %% [markdown]
# > b. (0.2 points) Compute the dot product between **x** and **y** and name it **q**

# %%
##Answer to question 1.1.1b
q = np.dot(x,y)
print(q)
# Out:
# 1057

# %% [markdown]
# > c. (0.2 points) **t** = pi(**s** + 4) (element wise multiplication)

# %%
##Answer to question 1.1.1c
import math
t = np.multiply(math.pi,(s+4))
print(t)
# Out:
# [326.72563597 322.95572479 319.1858136  315.41590242 311.64599124]

# %% [markdown]
# > d. (0.2 points) **z** = **z** - 1

# %%
##Answer to question 1.1.1d
z = z - 1
print(z)
# Out:
# [-0.3  0.   0.3  0.6  0.9  1.2  1.5  1.8]

# %% [markdown]
# > e. (0.2 points) replace some values of x, such that the last three values in the vector are 4

# %%
##Answer to question 1.1.1e
x[-3:] = 4
print(x)
# Out:
# [6 7 8 9 4 4 4]

# %% [markdown]
# > f. (0.2 points) **r** = 2**w** - 5

# %%
##Answer to question 1.1.1f
r = 2*w - 5
print(r)
# Out:
# [-3. -3. -5. -4. -3. -2. -1. -5. -5.]

# %% [markdown]
# **1.1.2** (0.25 points) Generate these matrices:
#
# \begin{equation}
#      \textbf{M} = \begin{pmatrix}
#          1 & 2 & 3 \\
#          6 & 8 & 4 \\
#          6 & 7 & 5
#          \end{pmatrix}
#      \textbf{N} = \begin{pmatrix}
#          4 & 6 \\
#          7 & 2 \\
#          5 & 1
#          \end{pmatrix}
#      \textbf{P} = \begin{pmatrix}
#          2 & 5 \\
#          5 & 5
#          \end{pmatrix}
# \end{equation}
#
# Afterwards try and compute the operations for subquestions *a* up to and including *e* and print the resulting matrix. If some operations yield errors, give the reason as to why that happens.
#
# *A hint: NumPy has functions for matrix operations you can, and should, use!*

# %%
##Generate the matrices using Python and NumPy
M = np.array([[1,2,3],[6,8,4],[6,7,5]])
N = np.array([[4,6],[7,2],[5,1]])
P = np.array([[2,5],[5,5]])

print(M)
print(N)
print(P)
# Out:
# [[1 2 3]
#  [6 8 4]
#  [6 7 5]]
# [[4 6]
#  [7 2]
#  [5 1]]
# [[2 5]
#  [5 5]]

# %% [markdown]
# > a. (0.2 points) **A** = **MN** + **N**

# %%
##Answer to question 1.1.2a
A = np.dot(M,N) + N
print(A)
# Out:
# [[ 37  19]
#  [107  58]
#  [103  56]]

# %% [markdown]
# > b. (0.2 points) **B** = **N**<sup>T</sup>**M**

# %%
##Answer to question 1.1.2b
B= np.dot(N.transpose(), M)
print(B)
# Out:
# [[76 99 65]
#  [24 35 31]]

# %% [markdown]
# > c. (0.2 points) **C** = **P**<sup>-1</sup> + **P**

# %%
##Answer to question 1.1.2c
C = np.linalg.inv(P) + P
print(C)
# Out:
# [[1.66666667 5.33333333]
#  [5.33333333 4.86666667]]

# %% [markdown]
# > d. (0.2 points) **D** = **AC**(**C** + **B**)

# %%
##Answer to question 1.1.2d
D = np.dot(A,np.dot(C,(np.add(C,B))))
print(D)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-597f48cfc0ad> in <module>
#       1 ##Answer to question 1.1.2d
# ----> 2 D = np.dot(A,np.dot(C,(np.add(C,B))))
#       3 print(D)
#
# ValueError: operands could not be broadcast together with shapes (2,2) (2,3)

# %% [markdown]
# Array C and B are of different dimensions, they would need to be reshaped in order to be added up.

# %% [markdown]
# > e. (0.2 points) Compute the eigenvalues and eigenvectors of **M**, **N**, and **P** (and print them).

# %%
w, v = np.linalg.eig(M)
print("w", w)
print('v', v)
# Out:
# w [-1.26208735 14.26208735  1.        ]
# v [[-0.84234218  0.25759308  0.51507875]
#  [ 0.38109032  0.68324439 -0.71318597]
#  [ 0.38109032  0.68324439  0.47545731]]

# %%
w, v = np.linalg.eig(N)
print("w", w)
print('v', v)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-a36627a370b3> in <module>
# ----> 1 w, v = np.linalg.eig(N)
#       2 print("w", w)
#       3 print('v', v)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1302     a, wrap = _makearray(a)
#    1303     _assertRankAtLeast2(a)
# -> 1304     _assertNdSquareness(a)
#    1305     _assertFinite(a)
#    1306     t, result_t = _commonType(a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertNdSquareness(*arrays)
#     211         m, n = a.shape[-2:]
#     212         if m != n:
# --> 213             raise LinAlgError('Last 2 dimensions of the array must be square')
#     214
#     215 def _assertFinite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %% [markdown]
# In order to calculate the eigenvalues, the matrix needs to be square, also as indicated by the linAlgError.

# %%
w, v = np.linalg.eig(P)
print("w", w)
print('v', v)
# Out:
# w [-1.72015325  8.72015325]
# v [[-0.80229293 -0.59693053]
#  [ 0.59693053 -0.80229293]]

# %% [markdown]
# ## 1.2 Principal Component Analysis
#
# **1.2.1** many experimenters have a habit of using Microsoft Excel as their tool to record measurements from experiments. Fortunately Python can read Excel files. Various methods exist, of which the use of the Python library Pandas is arguably one of the easiest for the purpose of Data Mining.
#
# The data used in this exercise is based on data from a chemical sensor obtained from the NanoNose project[1]. The data contains 8 sensors, named by the letters A-H, measuring the concentration of Water, Ethanol, Acetone, Heptane and Pentanol injected into a small gas chamber. The data will be represented in matrix form such that each column contains the 8 sensor measurements (i.e., sensor A-H) of the various compounds injected into the gas chamber.
# > a. (0.2 points) Inspect the nanonose.xls file in the Data folder and make sure you understand how the data is stored in Excel.
#
# > *Load the data in python using the Pandas library (use the read_excel() function). Make sure you read some of the Pandas documentation! Especially slicing, indexing and dropping are useful commands*
#
# > *make sure to inspect the data first! You should cut out some rows and columns! You can easily inspect the structure of the Pandas dataframe using the head() function.*
#
# > *Finally use the as_matrix() function to cast the Pandas dataframe to a NumPy array. Note: counterintuitively, this yields an object of type: numpy.ndarray, not of type numpy.matrix!*

# %%
import pandas as pd
excel_file = 'data/nanonose.xls'
nanonose = pd.read_excel(excel_file)

#Cleanup to remove the index row and apropriate columns
nanonose = nanonose.drop([0])
nanonose = nanonose.drop(nanonose.columns[:3], axis=1)
nanonose.head()

#Python advises me to use values instaed sinse as_matrix() will be removed in the future.
nanonose = nanonose.values

# %% [markdown]
# > b. (0.3 points) The data resides in what can be seen as an 8-dimensional space. Each dimension (column), corresponds to one of the 8 NanoNose sensors. Multidimensional (>3) data is hard to visualize, as we are unable to plot that many dimensions simultaneously.
#
# > Using the matplotlib library, plot the attributes A and B against each other. After you have plotted A against B, also plot a few other combinations of attributes. Plot at least 4 different combinations.
#
# > *Do not forget to label your axes and add a figure description!*
#
# > NOTE: If you want to plot inside the Jupyter notebook use the following command after you imported the library:
# *%matplotlib inline*

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.title("A versus B concentration") 
plt.xlabel("A conc.") 
plt.ylabel("B conc.")

plt.plot(nanonose[:,0], nanonose[:,1], ".")

# %%
plt.title("B versus C") 
plt.xlabel("B conc.") 
plt.ylabel("C conc.")

plt.plot(nanonose[:,1], nanonose[:,2], ".")

# %%
plt.title("C versus D") 
plt.xlabel("C conc.") 
plt.ylabel("D conc.")

plt.plot(nanonose[:,2], nanonose[:,3], ".")

# %%
plt.title("A versus H") 
plt.xlabel("A conc.") 
plt.ylabel("H conc.")

plt.plot(nanonose[:,0], nanonose[:,7], ".")

# %% [markdown]
# 1.2.2 Principal Component Analysis, more commonly known as PCA, can be cleverly used to better visualize high dimensional data.
#
# > a. (1 point) Explain what PCA is and when it can be used. Make sure to provide an in-depth explanation and note what the drawbacks and limitations are.

# %% [markdown]
# PCA (principle component analysis) is a way to project high dimension data on a vector and reducing the amount of dimensions in the process. This is done by finding the "Principle Component(s)" the eigenvalues eigenvector combination with the most magnitude from the centered covariance matrix. The data is then projected on this Principle Component.
#
# As a result you loose information of the covariance over a dimension, so if you reduce a lets say a 3d data matrix to a 2d data matrix you will remove the dimension with the least amount of covariance.
#
# Drawbacks are that you loose information about the covariance in the dimension(s) that are reduced.
# PCA has trouble with non linear relationships between values of attributes, as there will be no "line/plane" that can be drawn trough that would capture the covariance properly.

# %% [markdown]
# To apply PCA we must first mean center the data. mean centering means that the mean value for an attribute is subtracted from that attribute.
#
# > b. (0.5 points) Why do we first need to mean center the data before applying PCA?

# %% [markdown]
# To ensure we have a proper origin point.

# %% [markdown]
# In practice, applying PCA comes down to a series of matrix operations, this is useful, as matrix operations can be applied with little effort and can be computed in relatively little time.
#
# The given data **X**, must first be mean centered. This can be easily done by calculating a row vector **μ** containing the mean values of each attribute and then subtracting it from **X** (**Y** = **X** - **1μ**, where **1** is a column vector of size **N** x 1, with N indicating the number of observations in the original data).
#
# Then, the Singular Value Decomposition, or SVD, of **Y**, the mean centered data, can be calculated. **Y** = **USV**<sup>T</sup>. In practice, this is often done using the numpy.linalg.svd() function.
#
# Using SVD on **Y** yields a series of vectors which can be used to project the data onto specific Principal Components (PCs). The entire dataset can be projected onto the Principal Components by multiplying **Z** = **Y\*V**, where **Z** indicates the projected data. Alternatively, one could project onto just a subset of all the PCs by indexing in the multiplication. For example: **Z** = **Y\*V[:,1]** would yield the projection of the data onto the first PC.
#
# > c. (1 point)  Apply PCA (using the aforementioned method) on the Nanonose data and visualize a scatterplot of the projection of the data onto the first two PCs.

# %%
#Calc means
X = nanonose
u = np.mean(X,axis=0)
ones = np.ones((90,1))
Y = X-ones*u

U,S,V = np.linalg.svd(Y)
Z = np.dot(Y,V[:,:2])

plt.title("First two PC's of nanonose}") 
plt.xlabel("PC1") 
plt.ylabel("PC2")

plt.plot(Z[:,0], Z[:,1], ".")

# %% [markdown]
# > d. (1 point) Alternatively, one could use EigenValue Decomposition, EVD, instead of SVD. What are the similarities and differences between SVD and EVD? Can both be applied in each case?

# %% [markdown]
# SVD and EVD are both methods of describing a matrix in terms of its EigenValues or Singular Values, the diference is that SVD can be applied to non square matrixes and that its resulting matrices U and V are not (usually) the inverse of each other. where is in EVD they are namely V and V-1.

# %% [markdown]
# PCA attempts to explain as much of the variance in data with as few PCs as possible. The variance explained by each of the PCs **m** can be calculated using the following formula:
# $\rho_m = 1 - \frac{\|{Y} - {u}_m s_{mm} {v}_m^T\|^2_F}{\|{Y}\|^2_F} = \frac{s_{mm}^2}{\displaystyle \sum_{m'=1}^M s^2_{m'm'}}$
#
# Which indicates that the variation $\rho$ for a given **m** can be calculated by dividing the squared singular value of component **m** by the sum of all squared singular values.
# > e. (1 point) Calculate the row vector $\rho$ containing all values of $\rho$ for all PCs **m**. Create a bar plot with the variance explained on the Y axis and the number of the PC on the X axis.

# %%
p = np.square(S)/np.sum(np.square(S))
index = np.arange(start = 1, stop = 9)
plt.title("Explained Variance")
plt.xlabel("PC") 
plt.ylabel("Variance Explained")
plt.bar(index,p)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# > f. (0.5 points) How much of the variance is explained by the first three PCs?

# %%
p123 = sum(p[:2])*100
print(p123)
# Out:
# 87.84504496263415

# %% [markdown]
# So 87.85%

# %% [markdown]
# The columns of **V** indicate the exact projection of the data onto the PCs. In a way, a PC is nothing other than a linear combination of the original attributes.
# > g. (0.5 points) Which attributes are primarily represented by the first PC? What would cause an observation to have a large negative/positive projection onto the second principal component?

# %% [markdown]
# Attributes with high variance will be primarily represented by the first PC.

# %% [markdown]
# ## 1.3 Similarity measures
#
# We will use a subset of the data on wild faces described by Berg in 2005 transformed to a total
# of 1000 gray scale images of size 40x40 pixels, we will attempt to find faces in the
# data base that are the most similar to a given query face. To measure similarity we
# will consider the following measures: SMC, Jaccard, Cosine, ExtendedJaccard, and
# Correlation. These measures of similarity are described in *Introduction to Data Mining*, page 73-77 and are given by
#
# \begin{eqnarray*}
# \textrm{SMC}({x},{y}) & = & \frac{\textrm{Number of matching attribute values}}{\textrm{Number of attributes}} \\
# \textrm{Jaccard}({x},{y}) & = & \frac{\textrm{Number of matching presences}}{\textrm{Number of attributes not involved in 00 matches}} \\
# \textrm{Cosine}({x},{y}) & = & \frac{{x}^T {y}}{\|{x}\| \|{y}\|} \\
# \textrm{ExtendedJaccard}({x},{y}) & = & \frac{{x}^T {y}}{\|{x}\|^2 + \|{y}\|^2 - {x}^T {y}} \\
# \textrm{Correlation}({x},{y}) & = & \frac{\textrm{cov}({x},{y})}{\textrm{std}({x}) \textrm{std}({y})}
# \end{eqnarray*}
# where $\textrm{cov}({x},{y})$ denotes the covariance between ${x}$ and ${y}$ and $\textrm{std}({x})$ denotes the standard deviation of ${x}$.
#
# Notice that the SMC and Jaccard similarity measures only are defined for binary
# data, i.e., data that takes values in $\{0,1\}$. As the data we analyze is non-binary,
# we will transform the data to be binary when calculating these two measures of
# similarity by setting
# $x_i = \left\{ \begin{array}{ll} 0 & \textrm{if~} x_i < \textrm{median}({x}) \\
#                                 1 & \textrm{otherwise.} \end{array} \right.$
#
# ### 1.3.1
# > (0.5 points) Inspect and run the simfaces function from the Toolbox. The function loads the CBCL face database, computes the similarity between a selected query image and all others, and display the query image, the 5 most similar images, and the 5 least similar images. The value of the used similarity measure is shown below each image. Try changing the query image and the similarity measure and see what happens. Which similarity measures produce similar results? Which one gives the best result? Why?
#
# > Give a quick overview of the settings (image number and similarity measure) for each time you run the script! Remember to leave all results open!

# %%
from Toolbox.simfaces import simfaces
import random

n = random.randrange (0,1001,1)
print("SMC on image %i" % (n))
simfaces(n,'smc')
# Out:
# SMC on image 35

# %%
print("Jaccard on image %i" % (n))
simfaces(n,'jaccard')
# Out:
# Jaccard on image 35

# %%
print("Cosine on image %i" % (n))
simfaces(n,'cosine')
# Out:
# Cosine on image 35

# %%
print("ExtendedJaccard on image %i" % (n))
simfaces(n,'extendedjaccard')
# Out:
# ExtendedJaccard on image 35

# %%
print("Correlation on image %i" % (n))
simfaces(n,'correlation')
# Out:
# Correlation on image 35

# %% [markdown]
# Similar results:
# SMC, Jaccard and Cosine.
# For some algorithms the background color and general "brightness" of the image seems important, this seem be the case for:
# Jaccard and Cosine.
#
# If looking at just pixel similarity (which these algorithms do) and not at features the similarity between the sample and the top five is actually not that bad. To me it looks like Cosine does best but that may just be a coincidence with the random picture I choose.

# %% [markdown]
# > (0.75 points) We will investigate how scaling and translation impact the following three
# similarity measures: Cosine, ExtendedJaccard, and Correlation. Let $\alpha$ and $\beta$ be two constants. Using Python, calculate the following similarity measures, and check if the statements below are correct.
#
# \begin{eqnarray*}
# \textrm{Cosine}(\alpha{x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \textrm{ExtendedJaccard}(\alpha{x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \textrm{Correlation}(\alpha{x},{y}) & = & \textrm{Correlation}({x},{y}) \\
# \textrm{Cosine}(\beta + {x},{y}) & = & \textrm{Cosine}({x},{y}) \\
# \textrm{ExtendedJaccard}(\beta + {x},{y}) & = & \textrm{ExtendedJaccard}({x},{y}) \\
# \textrm{Correlation}(\beta + {x},{y}) & = & \textrm{Correlation}({x},{y})
# \end{eqnarray*}
#
# > Type help similarity, or study similarity.py, to learn about the function that is used to compute the similarity measures. Do not forget to also import similarity.py!
#
# > Even though a similarity measure is theoretically invariant e.g.\ to scaling, it might not be exactly invariant numerically.
#
# > Do not forget to also provide an explanation in addition to the calculations!

# %%
#Picking two totally random numbers.
alpha = 5
beta = 8

from Toolbox.similarity import similarity as sim
#Generate two random matrices to compare.
X = np.random.rand(3,3)
Y = np.random.rand(3,3)

print("Cosine(𝛼𝑥,𝑦) = Cosine(𝑥,𝑦)")
print(abs(sim(alpha*X,Y,"cos") - sim(X,Y,"cos")))

print("\n ExtendedJaccard(𝛼𝑥,𝑦) = ExtendedJaccard(𝑥,𝑦)")
print(sim(alpha*X,Y,"ext") - sim(X,Y,"ext"))

print("\nCorrelation(𝛼𝑥,𝑦) = Correlation(𝑥,𝑦)")
print(sim(alpha*X,Y,"cor") - sim(X,Y,"cor"))

print("\nCosine(𝛽 + 𝑥,𝑦) = Cosine(𝑥,𝑦)")
print(sim(beta + X,Y,"cos") - sim(X,Y,"cos"))

print("\nExtendedJaccard(𝛽 + 𝑥,𝑦) = ExtendedJaccard(𝑥,𝑦)")
print(sim(beta + X,Y,"ext") - sim(X,Y,"ext"))

print("\nCorrelation(𝛽 + 𝑥,𝑦) = Correlation(𝑥,𝑦)")
print(sim(beta + X,Y,"cor") - sim(X,Y,"cor"))
# Out:
# Cosine(𝛼𝑥,𝑦) = Cosine(𝑥,𝑦)
# [[2.22044605e-16 2.22044605e-16 2.22044605e-16]
#  [1.11022302e-16 2.22044605e-16 1.11022302e-16]
#  [1.11022302e-16 1.11022302e-16 0.00000000e+00]]
#
#  ExtendedJaccard(𝛼𝑥,𝑦) = ExtendedJaccard(𝑥,𝑦)
# [[-0.51239163 -0.46178181 -0.68968696]
#  [-0.31029285 -0.64033112 -0.37043913]
#  [-0.58036183 -0.62717781 -0.38604324]]
#
# Correlation(𝛼𝑥,𝑦) = Correlation(𝑥,𝑦)
# [[-1.11022302e-16 -2.22044605e-16  2.22044605e-16]
#  [ 1.11022302e-16  0.00000000e+00 -1.11022302e-16]
#  [ 0.00000000e+00 -5.55111512e-17  0.00000000e+00]]
#
# Cosine(𝛽 + 𝑥,𝑦) = Cosine(𝑥,𝑦)
# [[ 0.10745528  0.16428253 -0.07394188]
#  [ 0.05690823 -0.04348589  0.22011874]
#  [ 0.0613867   0.04143684  0.18155607]]
#
# ExtendedJaccard(𝛽 + 𝑥,𝑦) = ExtendedJaccard(𝑥,𝑦)
# [[-0.65789916 -0.54232814 -0.78577926]
#  [-0.59374775 -0.86487381 -0.45467881]
#  [-0.7423085  -0.73748329 -0.43717322]]
#
# Correlation(𝛽 + 𝑥,𝑦) = Correlation(𝑥,𝑦)
# [[-1.11022302e-16  1.11022302e-16  0.00000000e+00]
#  [ 1.22124533e-15  3.33066907e-16 -7.77156117e-16]
#  [-1.11022302e-16 -3.33066907e-16  2.22044605e-16]]

# %% [markdown]
# Wile doing scalar multiplication the difference in the similarity matrices of Cosine and Correlation are very small (rounding error small). while doing scalar addition the difference of Correlation is very small (again rounding error small).
#
# Indicating that Cosine and Correlation are not sensitive to scaling and Extended Jaccard is and Correlation is not sensitive to "moving" while Cosine and Extended Jaccard are.

# %% [markdown]
# ## Turning in the Jupyter Notebook
# Do not forget to read the provided guidelines regarding the expectations and grading of your report. You can find these on Blackboard!

# %% [markdown]
# ## References
# [1] Tommy S Alstrøm, Jan Larsen, Claus H Nielsen, and Niels B Larsen. Data-driven
# modeling of nano-nose gas sensor arrays. In SPIE Defense, Security, and Sensing,
# pages 76970U76970U. International Society for Optics and Photonics, 2010. URL
# http://www.nanonose.dk.
